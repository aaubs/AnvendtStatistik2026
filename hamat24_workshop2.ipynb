# %% [markdown]
# <a href="https://colab.research.google.com/github/aaubs/AnvendtStatistik2026/blob/main/hamat24_workshop2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Conceptual assignments with examples

# %% [markdown]
# ###2.1 Give two examples each of nominal, ordinal, and interval data.
#
# Here are the examples:
#
# **Nominal Data (No natural order between categories):**
# - Types of cuisine (e.g., Italian, Chinese, Indian, Mexican).
# - Car brands (e.g., Toyota, Ford, BMW, Mercedes).
#
# **Ordinal Data (Natural order between categories):**
# - Education levels (e.g., High School, Bachelor's, Master's, PhD).
# - Customer satisfaction ratings (e.g., Very Unsatisfied, Unsatisfied, Neutral, Satisfied, Very Satisfied).
#
# **Interval Data (No true zero point):**
# - Temperature in Celsius or Fahrenheit (e.g., 20°C, 35°C, 50°F, 70°F).
# - IQ scores (e.g., 90, 100, 110, 120).
#
# These examples illustrate the differences in the types of data: Nominal data categorizes without a natural order, ordinal data categorizes with a natural order but without a consistent scale between categories, and interval data has a consistent scale but no true zero point.

# %% [markdown]
# Here's an example of where it can be confusing (but methodically important) to distinquish between nominal and ordinal:

# %%
import pandas as pd

# Creating a DataFrame with specified columns and rows
data = {'Numerical_representation': [1, 2, 3],
        'Family_member (nominal)': ['Mom', 'Dad', 'Child'],
        'Degree (ordinal)': ['Bachelor Degree', 'Master Degree', 'PhD']}
df = pd.DataFrame(data)

df
# Out:
#    Numerical_representation Family_member (nominal) Degree (ordinal)
# 0                         1                     Mom  Bachelor Degree
# 1                         2                     Dad    Master Degree
# 2                         3                   Child              PhD

# %% [markdown]
# In this case, in order to use our data for statistical inference, we've had to create a numerical representation of our data points for Degree and Family. <br>
# The conceptual line at which the numerical representation changes between nominal and ordinal, is whether or not we can determine a sort of 'natural' ranking between the different data points. This natural order exists in Degree, making it **ordinal**. However we can not point out a 'natural' ranking between data points in Family, making it **nominal**. <br>

# %% [markdown]
# ### 2.2 Specify the Data Type for Each of the Following Data Examples
#
# - **a. The number of kilometers run by joggers per week:**
#   - *Data Type:* Interval Data
#   - *Explanation:* This data is quantitative and measures distance run, which can be ordered on a scale with equal intervals. However, it has no true zero point (negative distance is not possible), which is characteristic of interval data.
#
# - **b. Starting salary for Cand.merc graduates:**
#   - *Data Type:* Interval Data (more specifically Ratio Data)
#   - *Explanation:* Salaries are quantitative and have a true zero point (no salary). The differences and ratios between salary values are meaningful, making it fit as ratio data. However, within the context of the three specified types, it's closest to interval data with meaningful intervals.
#
# - **c. The months in which the company's employees choose to take a holiday:**
#   - *Data Type:* Nominal Data
#   - *Explanation:* The months are simply names of categories and do not have a natural order or ranking. They represent distinct groups without quantitative significance, typical of nominal data.
#
# - **d. Socio-economic status: high, medium, low:**
#   - *Data Type:* Ordinal Data
#   - *Explanation:* These categories represent a clear order (from high to low) but do not indicate specific quantitative differences or intervals between them, which is a defining characteristic of ordinal data.

# %% [markdown]
# ### 2.3 Determine the Data Type for Each of the Following Data Examples
#
# - **a. The weekly closing price of Amazon.com stock:**
#   - *Data Type:* Interval Data
#   - *Explanation:* The closing price of a stock is a numerical value on a continuous scale. The differences between values are meaningful, but the scale does not have a true zero point (a stock price can't be negative), making it interval data.
#
# - **b. The month with the highest unemployment rate at Hotel D’Angleterre:**
#   - *Data Type:* Nominal Data
#   - *Explanation:* The months are simply names of categories without any inherent order or scale. They represent distinct groups and cannot be quantitatively compared, fitting the criteria for nominal data.
#
# - **c. The size of the soda purchased by a sample of McDonald’s customers:**
#   - *Data Type:* Ordinal Data (if categorized by size like Small, Medium, Large)
#   - *Explanation:* If the soda sizes are categorized (e.g., Small, Medium, Large), they have a natural order but do not specify the exact volume, nor is the difference between sizes necessarily consistent. This ordered but non-quantitative nature makes it ordinal data.
#
# - **d. The number of Range Rovers imported to Denmark in the last 10 years:**
#   - *Data Type:* Interval Data (if treated as counts on a scale)
#   - *Explanation:* The number of vehicles imported is a numerical count. While it can be quantitatively compared, it lacks a meaningful zero point within the context of this example (the count starts from zero but represents an amount, not an absence), making it best suited as interval data.
#
# - **e. Legoland's annual revenue:**
#   - *Data Type:* Interval Data
#   - *Explanation:* Annual revenue is a numerical value that can be ordered and compared. However, since the scale does not have a true zero point (negative revenue is not an absence of revenue but indicates loss), it classifies as interval data.

# %% [markdown]
# ### 2.8 Determine the Data Type for Each of the Following Examples
#
# - **a. How many matches do you watch at the stadium annually?**
#   - *Data Type:* Interval Data
#   - *Explanation:* This data is numerical and can be measured on a scale with equal intervals. Each count (number of matches) is equidistant from the next, making it fit the characteristics of interval data.
#
# - **b. How do you rate the quality of the service experience at the stadium? (fantastic, very good, good, okay, bad)**
#   - *Data Type:* Ordinal Data
#   - *Explanation:* These responses are categorical and have a natural order (from 'fantastic' to 'bad'), but the intervals between these categories are not equal or quantifiable, typical of ordinal data.
#
# - **c. Do you have a season ticket?**
#   - *Data Type:* Nominal Data
#   - *Explanation:* This is a binary categorical variable (Yes/No), with no intrinsic ordering or ranking. Such categories are indicative of nominal data.
#
# - **d. How do you rate the quality of the food at the stadium? (super, good, bad)**
#   - *Data Type:* Ordinal Data
#   - *Explanation:* Similar to the service experience rating, these categories are ordered (from 'super' to 'bad') but do not have a defined scale between them. The lack of equal intervals makes it ordinal data.

# %% [markdown]
# ### 2.12 For a Sample of Car Owners, Determine the Data Type for Each of the Following Questions
#
# - **a. Car brand:**
#   - *Data Type:* Nominal Data
#   - *Explanation:* Car brands are categorical with no inherent order or ranking (unless you're a biased car-lover). Each brand is a distinct category, making this typical of nominal data.
#
# - **b. Age of the car in months:**
#   - *Data Type:* Interval Data
#   - *Explanation:* The age of a car measured in months is a numerical value. While it can be ordered and compared, it doesn't have a true zero point (a car cannot be less than 0 months old in a meaningful sense), aligning it with the properties of interval data.
#
# - **c. Annual amount paid for car insurance:**
#   - *Data Type:* Interval Data (more specifically Ratio Data)
#   - *Explanation:* This is a quantitative measure with a true zero point (no payment). The intervals and ratios between values are meaningful, making it ratio data. However, within the confines of the three data types, it's closest to interval data with meaningful intervals.
#
# - **d. Number of kilometers driven in the car:**
#   - *Data Type:* Interval Data
#   - *Explanation:* The number of kilometers is a quantitative measurement. It can be ordered and compared on a scale with equal intervals, but it does not have a true zero point (negative distance is not meaningful), making it fit the characteristics of interval data.

# %% [markdown]
# # Little nice-to-know options for data storage

# %% [markdown]
# Here I will very shortly introduce some options for data management, as I know that this can be a bit daunting at first. If you need further help setting up any of the specific options below, please come ask the supervisors during the workshops. This is strictly nice-to-know, and at this point at least we don't expect you to know all of this behind-the-scenes stuff.

# %% [markdown]
# ##Google Drive

# %% [markdown]
# The first one is to connect it directly to your Google Drive and use that as a file repository. Just like on your local machine, you will have a load of folders, and you'll need to make sure your file paths are correct when using it in code.

# %% [markdown]
# Remove the # on both lines if you want to try it out. For the sake of the notebook running without stop, they've been commented out

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# Now you're storage space in Google Colab is directly connected to your google drive, and you can save datasets, python files etc wheverever you want and easily access them elsewhere

# %% [markdown]
# ##Github Repository

# %% [markdown]
# **The second option** is to use a Github repository. <br> <br>
# 1. You simply go to Github.com, create a user login first. <br>
# 2. Next once you're logged in, on the left side of the webpage you'll see an option to create a new repository. <br>
# Create a repository, and give it a name. This will now function as your online file repository/storage. <br><br>
# **NB**: When you create the repository, there are 2 options you need to be aware of to make it work smoothly. First of this is the public/private setting. You'll want to set this to public to avoid a bunch of technical security set up. The second option is to 'Add a README file'. Make sure that the box is *checked*, so that a README file is generated. This just makes the UI a bit more beginner friendly from the get-go.

# %% [markdown]
# Now you simply extra the raw links of the dataset from Github and pull them straight into Google Colab. <br>
#
# You find the raw link by going to the file in Github like the first picture below illustrates. <br>
# 1. When you left-click on the file you're interested in, when dealing with .csv or just Excel files, you'll get a similar view as picture 2
# 2. Now, in the top right corner of picture 2, we get a button that says "Raw". This button will lead you to a 'raw' example of the file data, or in some cases just download a file straight away.
# 3. If you right-click the 'Raw' button you can now copy the URL link, and this you can use directly in your Google Colab notebook. <br><br>

# %% [markdown]
# **Picture 1**
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Picture 2**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# The link will look similar to what you've seen so far (this specific one is in a private repository you can't access) <br>
# https://github.com/CNielsen94/AAU_TA_Notebooks/raw/main/Datasets/HR-Employee-Attrition.csv

# %% [markdown]
# ## Download and upload files manually to Google Colab

# %% [markdown]
# Finally the third method, which is simply dragging and dropping data into Google Colab. On the right side of the Google Colab webpage you'll see a folder icon; <br>
#
# ![image.png](data:image/png;base64,...) <br>
#
# If you click this icon, it will simply open up the file manager for your current Google Colab session. By default it contains a folder named "sample_data", which you can open/inspect by clicking on it like any old file manager on your local machine. <br> To upload data you can either simply drag-and-drop the data into the space, or if you want to put it in a specific folder, you simply drag it there. Now you can either right-click the file and copy path / kopier filsti, and use that to read in your data.

# %% [markdown]
# Let's do an example using the default sample_data folder that comes with Colab.

# %%
# First I go to the file manager, and identify the file I want to load in
# In this case I want to try and read in california_housing_test.csv

df_cali_test = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %%
df_cali_test.head(2)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0

# %% [markdown]
# #Coding assignments

# %% [markdown]
# We will import and install the necessary libraries:

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ##**Assignment 2.13**
# When will the world run out of oil? One way to assess this is to look at oil reserves. Dataset Xr02-13 contains the known oil reserves for the top-15 oil-producing countries. Graphically describe this dataset in a bar chart in Excel and explain the result.

# %%
df2_13 = pd.read_excel('https://github.com/louisehviid/KM2023/raw/main/data/Chapter2/Xr02-13.xlsx')

# %% [markdown]
# First we get the exact column names for our inputs:

# %%
df2_13.columns
# Out:
# Index(['Country', 'Oil Reserves (Barrels)'], dtype='object')

# %% [markdown]
# Now we can set up the visualization

# %%
# Set the figure size (width, height)
plt.figure(figsize=(10, 6))
# Set the inputs df(x), df(y)
plt.bar(df2_13['Country'], df2_13['Oil Reserves (Barrels)'])
# Set label for X on the visualization
plt.xlabel('Country')
# Set label for Y on the visualization
plt.ylabel('Oil Reserves')
# Set the title on the visualization
plt.title('Known Oil Reserves of Top 15 Oil-Producing Countries')
# Add a bit of flair and readability by making each tick (country name) rotate by 45 degrees
plt.xticks(rotation=45)
# Finally, show the plot
plt.show()

# %% [markdown]
# ##Assignment 2.14

# %% [markdown]
# Use the Dataset from the Previous Exercise <br>
# The total oil reserve in the world is 1,689,078,618,100 barrels. The total oil reserve for the 15 countries included in the dataset is 1,563,350,000,000 barrels. Use a pie chart to illustrate the percentage distribution of oil across the countries in Excel (Python) and explain the result.

# %%
total_reserves_15_countries = 1.56335e12  # Total oil reserves for the 15 countries in barrels

# Calculate the percentage of the world's oil reserves for each country
df2_13['Percentage'] = (df2_13['Oil Reserves (Barrels)'] / total_reserves_15_countries) * 100

# Plotting the pie chart
plt.figure(figsize=(10, 8))

# Remember that the autopct and startangle are not necessary to run the code, just makes it look pretty.
plt.pie(df2_13['Percentage'], labels=df2_13['Country'], autopct='%1.1f%%', startangle=140)
plt.title('Percentage Distribution of Oil Reserves Among the Top 15 Countries')
plt.show()

# %% [markdown]
# ##Assignment 2.15

# %% [markdown]
# Dataset Xr02-15: Average Daily Oil Consumption of the Top 20 Oil-Consuming Countries <br>
# Dataset Xr02-15 contains the average daily oil consumption for the top 20 oil-consuming countries. Use a bar chart and a pie chart to illustrate this information in Excel and explain the results.

# %%
df2_15 = pd.read_excel('https://github.com/louisehviid/KM2023/raw/main/data/Chapter2/Xr02-15.xlsx')

# %%
df2_15.columns
# Out:
# Index(['Country', 'Consumption of oil (barrels per day)'], dtype='object')

# %% [markdown]
# Here, I'll plot both charts at the same time, by creating subplots. <br><br>
#
# If you look at the function: plt.subplot(1,2,1)
#
# - The first number (1) indicates the number of rows of subplots in the figure. In this case, we want just one row (horizontal), since we have 2 visualizations we want to put next to each other
# - The second number (2) indicates the number of columns (vertical) of subplots in the figure. Same reasoning as before, since we want 2 visualization next to each other, we need 1 row with 2 columns (one for each on the same row)
# - The third number (1) specifies the position of the subplot being created in the grid layout defined by the first two numbers. So where in our 1x2 frame do we want it? In this case, we place it in position 1

# %%
plt.figure(figsize=(12, 8))

# Bar chart
plt.subplot(1, 2, 1)
plt.bar(df2_15['Country'], df2_15['Consumption of oil (barrels per day)'])
plt.xlabel('Country')
plt.ylabel('Average Daily Oil Consumption')
plt.title('Bar Chart of Daily Oil Consumption')
plt.xticks(rotation=45)

# Pie chart
plt.subplot(1, 2, 2)
plt.pie(df2_15['Consumption of oil (barrels per day)'], labels=df2_15['Country'], autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart of Oil Consumption Distribution')

plt.tight_layout()
plt.show()

# %% [markdown]
# ##Assignment 2.16

# %% [markdown]
# 2.16 Distribution of Oil Production Across Product Categories <br>
# Oil production is distributed across various product categories. Dataset Xr02-16 contains information about the share of oil production across these product categories. Create a pie chart in Python to illustrate these figures and explain the result.

# %%
df2_16 = pd.read_excel('https://github.com/louisehviid/KM2023/raw/main/data/Chapter2/Xr02-16.xlsx')

# %%
df2_16.columns
# Out:
# Index(['Product', 'Proportion'], dtype='object')

# %%
plt.figure(figsize=(10, 8))

# Pie chart
plt.pie(df2_16['Proportion'], labels=df2_16['Product'], autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart of Oil Production Distribution by Product Category')

plt.show()

# %% [markdown]
# ##Assignment 2.17

# %% [markdown]
# 2.17 World Electricity Consumption <br>
# World electricity consumption is crucial information for ensuring adequate energy supply. The table in Xr02-17 shows the total electricity consumption measured in kilowatt-hours across a range of countries. Illustrate these figures graphically. Bonus question: Which variable would you add to the dataset to make the information about electricity consumption more comparable across countries? 1. Find this information on Google and add it to the dataset. Now, create a new graphical illustration of the dataset in a bar chart in Python and explain the result.

# %%
df2_17 = pd.read_excel('https://github.com/louisehviid/KM2023/raw/main/data/Chapter2/Xr02-17.xlsx')

# %%
df2_17.columns
# Out:
# Index(['Country', 'Electricity Consumption (Kilowatt-hours)'], dtype='object')

# %%
plt.figure(figsize=(12, 8))
plt.bar(df2_17['Country'], df2_17['Electricity Consumption (Kilowatt-hours)'])
plt.xlabel('Country')
plt.ylabel('Electricity Consumption (Kilowatt-hours)')
plt.title('Total Electricity Consumption by Country')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Population data found at: <br>
# https://data.worldbank.org/indicator/SP.POP.TOTL

# %%
df_extra = pd.read_csv('https://github.com/CNielsen94/Random_data_repo/raw/main/data/API_SP.POP.TOTL_DS2_en_csv_v2_6545436.csv')

# %%
df_extra['Country Name']
# Out:
# 0                            Aruba
# 1      Africa Eastern and Southern
# 2                      Afghanistan
# 3       Africa Western and Central
# 4                           Angola
#                   ...
# 261                         Kosovo
# 262                    Yemen, Rep.
# 263                   South Africa
# 264                         Zambia
# 265                       Zimbabwe
# Name: Country Name, Length: 266, dtype: object

# %% [markdown]
# Let's filter the new data by making a list of the countries in our original dataframe:

# %%
countries = list(df2_17['Country'])

# %%
countries
# Out:
# ['Australia',
#  'Brazil',
#  'Canada',
#  'China',
#  'France',
#  'Germany',
#  'India',
#  'Italy',
#  'Japan',
#  'Korea, South',
#  'Mexico',
#  'Russia',
#  'Saudi Arabia',
#  'South Africa',
#  'Spain',
#  'Taiwan',
#  'Turkey',
#  'United Kingdom',
#  'United States']

# %% [markdown]
# We need an overview of the columns in order to perform the filtering. We would like the latest population data, which is likely to be the column '2022'. So we want column '2022' for all the countries in our list.

# %%
df_extra.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        'Unnamed: 67'],
#       dtype='object')

# %% [markdown]
# First we create a filtered df to merge with, only adding the rows containing countries in our list

# %%
filtered_df = df_extra[df_extra['Country Name'].isin(countries)]

# %% [markdown]
# You might notice we're missing some (Russia and a few others). You'd want to find another data source all together ideally, or find a way to fill in those missing values with real data. For the sake of the example, we'll just go with them

# %%
filtered_df['Country Name']
# Out:
# 13          Australia
# 29             Brazil
# 35             Canada
# 40              China
# 55            Germany
# 70              Spain
# 77             France
# 81     United Kingdom
# 109             India
# 116             Italy
# 119             Japan
# 154            Mexico
# 205      Saudi Arabia
# 251     United States
# 263      South Africa
# Name: Country Name, dtype: object

# %% [markdown]
# I rename some column names to match up the dataframes, and then I select the column I am interested in adding, as well as which column it should merge based on (in this case we want to merge based on country to align the values correctly in the dataframe)

# %%
# Rename the column in filtered_df
filtered_df = filtered_df.rename(columns={'2022': 'Population', 'Country Name': 'Country'})

# Merge df2_17 with the population data from filtered_df
df2_17_with_population = df2_17.merge(filtered_df[['Country', 'Population']], on='Country', how='left')

# %% [markdown]
# We drop missing values, as these can cause weird issues. Ideally you should find more rigorous data sources instead

# %%
df2_17_with_population.dropna(inplace = True)

# %%
df2_17_with_population
# Out:
#            Country  Electricity Consumption (Kilowatt-hours)    Population
# 0        Australia                              222600000000  2.600554e+07
# 1           Brazil                              483500000000  2.153135e+08
# 2           Canada                              524800000000  3.892990e+07
# 3            China                             5523000000000  1.412175e+09
# 4           France                              451100000000  6.797131e+07
# 5          Germany                              540100000000  8.379798e+07
# 6            India                              864700000000  1.417173e+09
# 7            Italy                              303100000000  5.894042e+07
# 8            Japan                              921000000000  1.251250e+08
# 10          Mexico                              234000000000  1.275041e+08
# 12    Saudi Arabia                              231600000000  3.640882e+07
# ...

# %%
# Calculating electricity consumption per capita
df2_17_with_population['Electricity Consumption Per Capita'] = df2_17_with_population['Electricity Consumption (Kilowatt-hours)'] / df2_17_with_population['Population']

# Creating the bar chart for electricity consumption per capita
plt.figure(figsize=(12, 8))
plt.bar(df2_17_with_population['Country'], df2_17_with_population['Electricity Consumption Per Capita'])
plt.xlabel('Country')
plt.ylabel('Electricity Consumption Per Capita (Kilowatt-hours)')
plt.title('Electricity Consumption Per Capita by Country')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##Assignment 2.24

# %% [markdown]
# 2.24 Average Starting Salary for University Graduates <br>
# Each year, the Michigan State University Collegiate Employment Research Institute (CERI) conducts a survey to map out the starting salaries after completing university education. Dataset Xr02-24 shows the 18 university degrees that have the highest starting salary. The salary is the average starting salary measured in dollars across university graduates from more than 200 American universities. Use a bar chart in Python to illustrate and explain the results.

# %%
df2_24 = pd.read_excel('https://github.com/louisehviid/KM2023/raw/main/data/Chapter2/Xr02-23.xlsx')

# %%
df2_24.columns
# Out:
# Index(['University Degree', 'Average Starting Salary'], dtype='object')

# %%
# Assuming 'df2_24' is your DataFrame and it has columns 'Fruit' (representing university degrees) and 'Annual Production' (representing average starting salaries)
plt.figure(figsize=(12, 8))
plt.bar(df2_24['University Degree'], df2_24['Average Starting Salary'])
plt.xlabel('University Degree')
plt.ylabel('Average Starting Salary ($)')
plt.title('Average Starting Salaries for University Degrees')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##Assignment 3.13

# %% [markdown]
# 3.13 Customer Attendance in a Bank during the First Hour of Opening <br>
# The proportion of customers entering a bank during the first hour of opening time was recorded over 200 days. Create a histogram using dataset Xr03-13, describe its shape, and explain the results.

# %%
df3_32 = pd.read_excel('https://github.com/louisehviid/KM2023/raw/main/data/Chapter3/Xr03-32.xlsx')

# %%
df3_32.columns
# Out:
# Index(['Year', 'Part A (Hospital Insurance)'], dtype='object')

# %%
# Assuming 'df3_13' is your DataFrame and 'Part A (Hospital Insurance)' contains the attendance data
plt.figure(figsize=(10, 6))
plt.hist(df3_32['Part A (Hospital Insurance)'], bins=20, edgecolor='black')
plt.xlabel('Proportion of Customers')
plt.ylabel('Frequency')
plt.title('Histogram of Customer Attendance in the First Hour Over 200 Days')
plt.show()

# %% [markdown]
# ##Assignment 3.20

# %% [markdown]
# 3.20 Daily Book Shipments by Amazon.com
# The number of books Amazon.com dispatched daily was recorded over 100 days. Create a histogram using dataset Xr03-20 and explain the results.

# %%
import pandas as pd

# %%
df3_20 = pd.read_excel('https://github.com/louisehviid/KM2023/raw/main/data/Chapter3/Xr03-20.xlsx')

# %%
df3_20.columns
# Out:
# Index(['Books'], dtype='object')

# %%
import pandas as pd

# %%
df3_13 = pd.read_excel('https://github.com/louisehviid/KM2023/raw/main/data/Chapter3/Xr03-13.xlsx',sheet_name='Xr03-15')

# %%
df3_13.head
# Out:
# <bound method NDFrame.head of      Customers
# 0           54
# 1           29
# 2           32
# 3           37
# 4           26
# ..         ...
# 195         38
# 196         36
# 197         30
# 198         29
# 199         33
#
# [200 rows x 1 columns]>

# %%
df3_20.columns
# Out:
# Index(['Books'], dtype='object')

# %%
# Assuming 'df3_20' is your DataFrame and it has a column 'Books' representing daily book shipments
plt.figure(figsize=(10, 6))
plt.hist(df3_20['Books'], bins=20, edgecolor='black')
plt.xlabel('Number of Books Dispatched')
plt.ylabel('Frequency')
plt.title('Histogram of Daily Book Shipments by Amazon.com Over 100 Days')
plt.show()

# %% [markdown]
# ##Assignment 3.32

# %% [markdown]
# Medicare Part A Costs Since 1966<br>
# The U.S. government provides 'Medicare' to Americans aged 65 and older. Medicare Part A covers expenses for hospital and nursing care, but not doctors' bills. The data file Xr03-32 shows the costs of Medicare Part A since 1966. Create a line chart and explain what it shows.

# %%
df3_32 = pd.read_excel('https://github.com/louisehviid/KM2023/raw/main/data/Chapter3/Xr03-32.xlsx')
df3_32.columns
# Out:
# Index(['Year', 'Part A (Hospital Insurance)'], dtype='object')

# %%
plt.figure(figsize=(12, 6))
plt.plot(df3_32['Year'], df3_32['Part A (Hospital Insurance)'], marker='o')
plt.xlabel('Year')
plt.ylabel('Medicare Part A Costs')
plt.title('Medicare Part A Costs Since 1966')
plt.grid(True)
plt.show()

# %% [markdown]
# ##Assignment 3.56

# %% [markdown]
# 3.56 Testing a Professor's Theory on Exam Completion Time and Student Performance <br>
# A statistics professor had a theory that students who completed their exams more quickly also performed better than those who handed in later. To gather data to examine the validity of her theory, she recorded the time (in minutes) students spent before submitting their exams (with a 90-minute limit) and the subsequent grades for a sample of 12 students. Create a scatter plot using dataset Xr03-56 and describe what it tells you about the professor's theory.

# %%
df3_56 = pd.read_excel('https://github.com/louisehviid/KM2023/raw/main/data/Chapter3/Xr03-56.xlsx')
df3_56.columns
# Out:
# Index(['Time', 'Mark'], dtype='object')

# %%
# Assuming 'df3_56' is your DataFrame and it has columns 'Time' and 'Mark'
plt.figure(figsize=(10, 6))
plt.scatter(df3_56['Time'], df3_56['Mark'])
plt.xlabel('Time to Complete Exam (minutes)')
plt.ylabel('Mark')
plt.title('Relationship Between Exam Completion Time and Student Performance')
plt.grid(True)
plt.show()

# %% [markdown]
# Alternatively, with a red trend line;

# %%
import numpy as np

# Assuming 'df3_56' is your DataFrame with columns 'Time' and 'Mark'
x = df3_56['Time']
y = df3_56['Mark']

# Creating the scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(x, y)

# Calculating the trend line
m, b = np.polyfit(x, y, 1)
plt.plot(x, m*x + b, color='red')  # This adds the trend line

# Adding labels and title
plt.xlabel('Time to Complete Exam (minutes)')
plt.ylabel('Mark')
plt.title('Relationship Between Exam Completion Time and Student Performance')

# Show grid and plot
plt.grid(True)
plt.show()

# %% [markdown]
# #FAQ

# %% [markdown]
# ##Where are my files? Where did my data go?

# %% [markdown]
# First off: Did you manually download and upload something, or did you try to load it in from where? <br>
#
# **If you manually downloaded something**, it's likely in your local folder called "Downloads" (Overførsler på dansk), and you can find it there by either searching for the name or filtering based on latest activity. Once you've located your file, you can follow the instructions in the nice-to-know section. <br><br>
# **If you tried to load in your dataset from somewhere else**, it can be for a number of reasons, first of which is the URL you're using. Make sure you copy the correct file-path (filsti). Secondly, make sure you're actually allowed to pull it from whereever you're trying to pull it from (difference between public and private repo is external access).

# %% [markdown]
# ## How do you guys know how to write/correct your and our code? Are you geniuses?

# %% [markdown]
# Hell no, but we've spent ungodly amounts of time crying over our own broken code to learn the basic concepts. <br><br>
# Truth is, we fail just as much (if not more) than you do. We just have more practice in Googling and looking up solutions. A quick way to look up any code, is to go to google and write something along the lines of "Bar chart Matplotlib", and you'll get a thousand examples. <br><br>
# After that you just gotta determnine what inputs (X and y) to visualize, and that's typically all there is to it. <br><br>
# If you get an error message at any point, an issue way to look for possible solutions is to simply copy paste it into google and see how other people solved it. <br><br>
#
# Final solution is to ask ChatGPT to code up an initial structure for us, HOWEVER this is a really bad way to get started in understanding how all this data management and coding works. You have to learn how to input variables, select dataframe columns etc. The blood, sweat and tears will pay off in your following years of academia, so only use ChatGPT as a guide or start to look up stuff on your own.

# %% [markdown]
# ## How do I read a url / filepath?

# %%
df_cali_test = pd.read_csv('/content/sample_data/california_housing_test.csv')

# %% [markdown]
# Let's try and break up the links we use to load in data, in order to make it a bit more understandable <br>
#
# We got /content/, /sample_data/ and california_housing_test.csv <br><br>
#
# The first 2 of these, content and sample_data, refers to the folders that the file is in. So in this case, we want to access the file named 'california_housing_test.csv' inside the folder 'sample_data', which is inside the folder 'content'. <br> <br>
# So the structure is: content (main folder) / sample_data (subfolder) / california_housing_test.csv (data file)<br><br>
# In this case, 'content' is just the default folder everything goes in if Google Drive or something similar isn't connected.
